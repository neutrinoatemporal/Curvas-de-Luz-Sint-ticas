# %%
import numpy as np
from potencial import curva_potencial

# %% [markdown]
# Curva de luz

# %% [markdown]
# ASAS 203113+0513.2

# %%
curva_potencial(np.deg2rad(77.06),0.914,6.017 , 4.384,1.282)

# %% [markdown]
# ASAS 011416+0426.4

# %%
curva_potencial(np.deg2rad(88.323),0.808,9.763 , 11.359,0.299)
