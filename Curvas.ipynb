# %%
import numpy as np
from main import curva

# %% [markdown]
# Curvas de Luz de las estrellas

# %% [markdown]
# ASAS 203113+0513.2

# %%
curva(np.deg2rad(77.06),0.914,0.2,0.281,1.282)

# %% [markdown]
# ASAS 011416+0426.4

# %%
curva(np.deg2rad(88.323),0.808,0.113,0.081,0.299)

# %% [markdown]
# ASAS 010538-8003.7

# %%
curva(np.deg2rad(80.4), 1.003 , 0.135 , 0.174 , 0.444)

# %% [markdown]
# ASAS 023631+1208.6

# %%
curva(np.deg2rad(87.4), 0.839 , 0.136 , 0.096 , 0.471)

# %% [markdown]
# ASAS 085524-4411.3

# %%
curva(np.deg2rad(86.4), 0.8772  , 0.092 , 0.081 , 0.751)

# %% [markdown]
# ASAS 150145-5242.2

# %%
curva(np.deg2rad(84.7),   1.002  , 0.136 , 0.134 , 0.981)

# %% [markdown]
# ASAS 155259-6637.8

# %%
curva(np.deg2rad( 84.5), 1.214  , 0.094 , 0.145 , 2.211)

# %% [markdown]
# ASAS 155358-5553.4

# %%
curva(np.deg2rad( 86.3),1.043 , 0.131 , 0.143, 1.062)

# %% [markdown]
# ASAS 174626-1153.0

# %%
curva(np.deg2rad(81.4), 1.21  , 0.158 , 0.209 , 1.433)

# %% [markdown]
# ASAS 193044+1340.3

# %%
curva(np.deg2rad(87.6),  0.930 , 0.161 , 0.127 , 0.559)

# %% [markdown]
# ASAS 195113-2030.2

# %%
curva(np.deg2rad(83.4 ),  0.7211 , 0.125 , 0.093 , 0.536)
